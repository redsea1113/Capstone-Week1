# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera
#
# ### Done by Ali Farhat
#
# ### Bronx Middle Estern Resturants

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project, I am interested in The **Bronx** neighborhood. The Bronx has a rich
# history and has passed through many stages in it is history. Its history during
# the 20th century may be divided into four periods: a boom period during 1900–
# 29, with a population growth by a factor of six from 200,000 in 1900 to 1.3 million
# in 1930. The Great Depression and post-World War II years saw a slowing of
# growth leading into an eventual decline. The mid to late century were hard times,
# the Bronx declined 1950–85 from a predominantly moderate-income to a
# predominantly lower-income area with high rates of violent crime and poverty.
# The Bronx has experienced an economic and developmental resurgence starting
# in the late 1980s that continues into today.
#
# As a **Middle Eastern**, I always had a passion to open a **Middle Eastern
# restaurant.** As we all aware location is the primary success factor in restaurant
# business. The Bronx is ideal for opening a Middle Eastern restaurant due to its
# diversity. My problem is to find the **proper location** that will give me a
# competitive edge but yet an attraction zoon. The competition is going to be high
# so in my study, I will look for neighborhoods with many restaurants but with few Middle
# Eastern options.
#
# **Target Audience :**
# The target audience of this report is any one that is interested in opening a Middle Eastern
# restaurant in the Bronx. Since my dream is to open a Middle Eastern restaurant that then
# the main targeted audience is myself and my family.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The data comes from New York Geo Data Center from the following link
# https://geo.nyu.edu/catalog/nyu_2451_34572. The data contains neighborhood
# information the larger city of New York. The data is formatted in JSON objects
#
#
#
#
# The JSON object include many elements that will be relevant to our study. From the JSON object we
# are interested in the following attributes:
#
# <UL>
#     <li> properties.name : Which is the neighborhood
# <li> properties.borough : Which is the city, in which we are looking for the Bronx
#     <li> geometry.coordinates : That contains two values, latitude and longitude
# </UL>

# %% [markdown]
# # Downloading and preparing the data and installing necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.8.28-0                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.9.11-py36_0              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_2             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Dataset

# %% [markdown]
# Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to segement the neighborhoods and explore them, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood.
#
# Luckily, this dataset exists for free on the web. Feel free to try to find this dataset on your own, but here is the link to the dataset: https://geo.nyu.edu/catalog/nyu_2451_34572

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %% [markdown]
# #### Load and explore the data
#
# Lets also read the  json data

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %% [markdown]
# ## Tranform the data into a *pandas* dataframe
#
# ### As mentioned above from the JSON, we are interested the the following attributes.  So we create a pandas dataframe and populate it with the json data objects

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# ## Populate the data frame with data downloaded

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
# Review the neighborhood Data 
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
# Extract Only Bronx Data 

bronx_data = neighborhoods[neighborhoods['Borough'] == 'Bronx'].reset_index(drop=True)
bronx_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# ### Neighborhood Of interests
#
# Let's create latitude & longitude coordinates for centroids of our candidate neighborhoods. We will create a grid of cells covering our area of interest which is aprox. 500 m radious around the center of the bronx city center.
#
# Let's first find the latitude & longitude of bronx city center, using specific, well known address and Google Maps geocoding API.

# %%
# Drwa Bronx Neighborhood
address = 'Bronx, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate for the bronx are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate for the bronx are 40.85048545, -73.8404035580209.

# %%
# create map of The Bronx  using latitude and longitude values
map_bronx = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(bronx_data['Latitude'], bronx_data['Longitude'], bronx_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bronx)  
    
map_bronx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Use Foursequer to get Resturants
#
# The next step is to take at all the neighborhoods in the Bronx using the latitude and longitude and get
# the **100 restaurant venues within a radius of 500 meters**. The source of the data related to the venues
# comes from the FourSquares.
# The request to FourSquares is formatted in the following manner

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
# @hidden_cell

CLIENT_ID = 'IX3XTPJPMM4TGAOEUORCXYKC0K13Y3KCR5YN3TZ0KCZN15ZG' # your Foursquare ID
CLIENT_SECRET = 'DZYZJBO2M0NNJNTNU2UQG4B5PIDYXGJ1KR1PNRJALYRGCO3M' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 30

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IX3XTPJPMM4TGAOEUORCXYKC0K13Y3KCR5YN3TZ0KCZN15ZG
# CLIENT_SECRET:DZYZJBO2M0NNJNTNU2UQG4B5PIDYXGJ1KR1PNRJALYRGCO3M

# %%
neighborhood_latitude = bronx_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = bronx_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = bronx_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Wakefield are 40.89470517661, -73.84720052054902.

# %% [markdown]
# ### Now, let's get the top 100 venues that are in  within a radius of 1000 meters of wakefield .
#
# ### Create a url that gets the data from forsquares

# %%
# type your answer here

LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 1000 # define radius
CATID = '4bf58dd8d48988d115941735'


# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT, 
    CATID)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=IX3XTPJPMM4TGAOEUORCXYKC0K13Y3KCR5YN3TZ0KCZN15ZG&client_secret=DZYZJBO2M0NNJNTNU2UQG4B5PIDYXGJ1KR1PNRJALYRGCO3M&v=20180605&ll=40.89470517661,-73.84720052054902&radius=1000&limit=100'

# %% [markdown]
# Execute a get command to Forusquares and get the result in JSON

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5db85029a30619002c46a5c1'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Wakefield',
#   'headerFullLocation': 'Wakefield, Bronx',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 44,
#   'suggestedBounds': {'ne': {'lat': 40.903705185610015,
#     'lng': -73.83531662200086},
#    'sw': {'lat': 40.88570516760999, 'lng': -73.85908441909719}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c537892fd2ea593cb077a28',
#        'name': 'Lollipops Gelato',
#        'location': {'address': '4120 Baychester Ave',
#         'crossStreet': 'Edenwald & Bussing Ave',
#         'lat': 40.894123150205274,
#         'lng': -73.84589162362325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.894123150205274,
#           'lng': -73.84589162362325}],
#         'distance': 127,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4120 Baychester Ave (Edenwald & Bussing Ave)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c537892fd2ea593cb077a28-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d375ce799fe8eec99fd2355',
#        'name': 'Ripe Kitchen & Bar',
#        'location': {'address': '151 W Sandford Blvd',
#         'crossStreet': 'South 11th Avenue',
#         'lat': 40.898151685683544,
#         'lng': -73.83887499584462,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.898151685683544,
#           'lng': -73.83887499584462}],
#         'distance': 798,
#         'postalCode': '10550',
#         'cc': 'US',
#         'neighborhood': 'South Side',
#         'city': 'Mount Vernon',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['151 W Sandford Blvd (South 11th Avenue)',
#          'Mount Vernon, NY 10550',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d375ce799fe8eec99fd2355-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9e50e38afca09379b2ff15',
#        'name': "Ali's Roti Shop",
#        'location': {'address': '4216 White Plains Rd',
#         'crossStreet': 'Between 233rd and 234th street',
#         'lat': 40.89403569556059,
#         'lng': -73.8569349369388,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89403569556059,
#           'lng': -73.8569349369388}],
#         'distance': 822,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4216 White Plains Rd (Between 233rd and 234th street)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9e50e38afca09379b2ff15-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c10f6aece57c92804a682d2',
#        'name': "Jackie's West Indian Bakery",
#        'location': {'address': '1203 E 233rd St',
#         'crossStreet': 'Baychester Aveue',
#         'lat': 40.88928305984094,
#         'lng': -73.84330953453158,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.88928305984094,
#           'lng': -73.84330953453158}],
#         'distance': 686,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1203 E 233rd St (Baychester Aveue)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c10f6aece57c92804a682d2-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6af9426107f04dedeb297a',
#        'name': 'Rite Aid',
#        'location': {'address': '4232 Baychester Ave',
#         'lat': 40.896649,
#         'lng': -73.8448461,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.896649,
#           'lng': -73.8448461}],
#         'distance': 293,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4232 Baychester Ave',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6af9426107f04dedeb297a-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c783cef3badb1f7e4244b54',
#        'name': 'Carvel Ice Cream',
#        'location': {'address': '1006 E 233rd St',
#         'lat': 40.890486685759605,
#         'lng': -73.84856772568665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.890486685759605,
#           'lng': -73.84856772568665}],
#         'distance': 483,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1006 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c783cef3badb1f7e4244b54-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1bed4eb306c928140763b7',
#        'name': "Jimbo's",
#        'location': {'address': '4137 White Plains Rd',
#         'crossStreet': '231st Street',
#         'lat': 40.89174013088267,
#         'lng': -73.85822584571335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89174013088267,
#           'lng': -73.85822584571335}],
#         'distance': 984,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4137 White Plains Rd (231st Street)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1bed4eb306c928140763b7-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4beda0fc6e8c20a14aa97061',
#        'name': 'Rite Aid',
#        'location': {'address': '1179 E 233rd St',
#         'lat': 40.8890623,
#         'lng': -73.8429927,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8890623,
#           'lng': -73.8429927}],
#         'distance': 721,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1179 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4beda0fc6e8c20a14aa97061-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c25c212f1272d7f836385c5',
#        'name': "Dunkin'",
#        'location': {'address': '980 E 233rd St',
#         'crossStreet': 'Paulding Ave',
#         'lat': 40.8904587811365,
#         'lng': -73.84908886747644,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8904587811365,
#           'lng': -73.84908886747644}],
#         'distance': 498,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['980 E 233rd St (Paulding Ave)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1163688',
#         'url': 'https://www.seamless.com/menu/dunkin-980-e-233rd-st-bronx/1163688?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1163688',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c25c212f1272d7f836385c5-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '508af256e4b0578944c87392',
#        'name': 'Cooler Runnings Jamaican Restaurant Inc',
#        'location': {'address': '1802 Nereid Ave',
#         'crossStreet': 'Wickham',
#         'lat': 40.89827622104366,
#         'lng': -73.85038105139019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89827622104366,
#           'lng': -73.85038105139019}],
#         'distance': 479,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1802 Nereid Ave (Wickham)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-508af256e4b0578944c87392-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d33665fb6093704b80001e0',
#        'name': 'SUBWAY',
#        'location': {'address': '980 E 233rd St',
#         'lat': 40.89065631618457,
#         'lng': -73.84919159087512,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89065631618457,
#           'lng': -73.84919159087512}],
#         'distance': 480,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['980 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '293568',
#         'url': 'https://www.seamless.com/menu/subway-980-e-233rd-st-bronx/293568?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=293568',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d33665fb6093704b80001e0-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c81a91c51ada1cd87741510',
#        'name': 'Shell',
#        'location': {'address': '836 E 233rd St',
#         'lat': 40.894187118166535,
#         'lng': -73.84586195733382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.894187118166535,
#           'lng': -73.84586195733382}],
#         'distance': 126,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['836 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c81a91c51ada1cd87741510-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1aa37fb9f876b098fc7846',
#        'name': 'T-Mobile',
#        'location': {'address': '4198 White Plains Rd',
#         'crossStreet': 'E 233rd St',
#         'lat': 40.893263930471456,
#         'lng': -73.85722409127993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.893263930471456,
#           'lng': -73.85722409127993}],
#         'distance': 858,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4198 White Plains Rd (E 233rd St)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#          'name': 'Mobile Phone Shop',
#          'pluralName': 'Mobile Phone Shops',
#          'shortName': 'Mobile Phones',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1aa37fb9f876b098fc7846-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3b2b9a1495bf24a5bcf1cb',
#        'name': 'Walgreens',
#        'location': {'address': '4401 White Plains Rd',
#         'lat': 40.89875681347848,
#         'lng': -73.85444551706314,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89875681347848,
#           'lng': -73.85444551706314}],
#         'distance': 758,
#         'postalCode': '10470',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4401 White Plains Rd',
#          'Bronx, NY 10470',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3b2b9a1495bf24a5bcf1cb-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd3edd25366548131a129ed',
#        'name': 'E&L Bakery',
#        'location': {'address': '4202 White Plains Rd',
#         'crossStreet': '233rd Street',
#         'lat': 40.89368628873347,
#         'lng': -73.85723405629689,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89368628873347,
#           'lng': -73.85723405629689}],
#         'distance': 851,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4202 White Plains Rd (233rd Street)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1163727',
#         'url': 'https://www.seamless.com/menu/e--l-bakery-cafe-4202-white-plains-rd-bronx/1163727?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1163727',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '77053551'}},
#       'referralId': 'e-0-4cd3edd25366548131a129ed-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf5c0a294b2a5937c42acee',
#        'name': 'Golden Krust Caribbean Restaurant',
#        'location': {'address': '4182 White Plains Road',
#         'lat': 40.89286268849937,
#         'lng': -73.85759437940986,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89286268849937,
#           'lng': -73.85759437940986}],
#         'distance': 898,
#         'postalCode': '10462',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4182 White Plains Road',
#          'Bronx, NY 10462',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'shortName': 'Caribbean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf5c0a294b2a5937c42acee-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdc00132a3a0f47cd42b1b6',
#        'name': "Dunkin'",
#        'location': {'address': '4399A White Plains Rd',
#         'crossStreet': 'Nereid Ave',
#         'lat': 40.89838958635662,
#         'lng': -73.85464265921001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89838958635662,
#           'lng': -73.85464265921001}],
#         'distance': 748,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4399A White Plains Rd (Nereid Ave)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdc00132a3a0f47cd42b1b6-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e17245245ddc623eb0f8fc6',
#        'name': 'Foodtown',
#        'location': {'lat': 40.896418935039556,
#         'lng': -73.85564224112738,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.896418935039556,
#           'lng': -73.85564224112738}],
#         'distance': 735,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Bronx, NY 10466', 'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e17245245ddc623eb0f8fc6-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6dbb78f964a520968a2ce3',
#        'name': "Domino's Pizza",
#        'location': {'address': '686C Nereid Ave',
#         'lat': 40.89844256649264,
#         'lng': -73.85485053062439,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89844256649264,
#           'lng': -73.85485053062439}],
#         'distance': 766,
#         'postalCode': '10470',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['686C Nereid Ave',
#          'Bronx, NY 10470',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6dbb78f964a520968a2ce3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be5f0eacf200f47d1fa133c',
#        'name': "McDonald's",
#        'location': {'address': '724 E 241st St',
#         'lat': 40.90264544569362,
#         'lng': -73.84948544204235,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.90264544569362,
#           'lng': -73.84948544204235}],
#         'distance': 904,
#         'postalCode': '10470',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['724 E 241st St',
#          'Bronx, NY 10470',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1338352',
#         'url': 'https://www.seamless.com/menu/mcdonalds-724-e-241st-st-bronx/1338352?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1338352',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be5f0eacf200f47d1fa133c-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb533867beb65c72e11e47f',
#        'name': 'Chase Bank',
#        'location': {'address': '725 E 233rd St',
#         'lat': 40.893297,
#         'lng': -73.856222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.893297,
#           'lng': -73.856222}],
#         'distance': 775,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['725 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb533867beb65c72e11e47f-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59ea0da7872f7d28f0f4f428',
#        'name': 'Shell',
#        'location': {'address': '836 E 233rd St',
#         'lat': 40.89190142,
#         'lng': -73.8532626,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89190142,
#           'lng': -73.8532626}],
#         'distance': 598,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['836 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59ea0da7872f7d28f0f4f428-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc718002271f2705156356b',
#        'name': 'Fine Fare',
#        'location': {'address': '1199 E 233rd St',
#         'lat': 40.88924476474482,
#         'lng': -73.84357937403945,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.88924476474482,
#           'lng': -73.84357937403945}],
#         'distance': 679,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1199 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc718002271f2705156356b-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dda9be4c65bee535afd6d2e',
#        'name': 'Capital One Bank',
#        'location': {'address': '4201 White Plains Rd',
#         'lat': 40.89374018544049,
#         'lng': -73.85745366780156,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89374018544049,
#           'lng': -73.85745366780156}],
#         'distance': 869,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4201 White Plains Rd',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dda9be4c65bee535afd6d2e-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8e4302ad70a143700f880f',
#        'name': 'Popeyes Louisiana Kitchen',
#        'location': {'address': '1201 E 233rd St',
#         'crossStreet': 'Baychester Ave.',
#         'lat': 40.889322016018355,
#         'lng': -73.84332313766208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.889322016018355,
#           'lng': -73.84332313766208}],
#         'distance': 682,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1201 E 233rd St (Baychester Ave.)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1278694',
#         'url': 'https://www.seamless.com/menu/popeyes-1201-e-233rd-st-bronx/1278694?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1278694',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8e4302ad70a143700f880f-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bab4c66f964a520be9e3ae3',
#        'name': "Dunkin'",
#        'location': {'address': '712 E 233rd St',
#         'crossStreet': 'White Plains Rd',
#         'lat': 40.89306385538046,
#         'lng': -73.85697719386576,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89306385538046,
#           'lng': -73.85697719386576}],
#         'distance': 842,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['712 E 233rd St (White Plains Rd)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d148941735',
#          'name': 'Donut Shop',
#          'pluralName': 'Donut Shops',
#          'shortName': 'Donuts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1162448',
#         'url': 'https://www.seamless.com/menu/dunkin-712-e-233rd-st-bronx/1162448?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1162448',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bab4c66f964a520be9e3ae3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4e0e38bd4101d0d7a12e00',
#        'name': "McDonald's",
#        'location': {'address': '1201 E 233rd St',
#         'lat': 40.8913759474037,
#         'lng': -73.85163239095422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8913759474037,
#           'lng': -73.85163239095422}],
#         'distance': 525,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1201 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4e0e38bd4101d0d7a12e00-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c239a63136d20a14775e061',
#        'name': 'Rite Aid',
#        'location': {'address': '4159 White Plains Rd',
#         'crossStreet': 'E 231st St',
#         'lat': 40.892241,
#         'lng': -73.8582369,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.892241,
#           'lng': -73.8582369}],
#         'distance': 968,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4159 White Plains Rd (E 231st St)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c239a63136d20a14775e061-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc256eb920eb713cd1b1c2c',
#        'name': "McDonald's",
#        'location': {'address': '4174 White Plains Rd',
#         'lat': 40.892779,
#         'lng': -73.857473,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.892779,
#           'lng': -73.857473}],
#         'distance': 890,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4174 White Plains Rd',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1339326',
#         'url': 'https://www.seamless.com/menu/mcdonalds-4174-white-plains-rd-bronx/1339326?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1339326',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc256eb920eb713cd1b1c2c-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd49e342944b1f7623458ec',
#        'name': 'Shell',
#        'location': {'address': '1217 E 233rd St',
#         'crossStreet': 'Bussing Ave',
#         'lat': 40.886595957614354,
#         'lng': -73.84916287540008,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.886595957614354,
#           'lng': -73.84916287540008}],
#         'distance': 917,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1217 E 233rd St (Bussing Ave)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd49e342944b1f7623458ec-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe730782a2ef3be56d2bd2',
#        'name': 'Associated Supermarket',
#        'location': {'address': '4141 Laconia Ave',
#         'lat': 40.88796975874366,
#         'lng': -73.84692879859317,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.88796975874366,
#           'lng': -73.84692879859317}],
#         'distance': 750,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4141 Laconia Ave',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe730782a2ef3be56d2bd2-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4edbac4e775bcc53fc0ed5f8',
#        'name': 'Hong Kong China King',
#        'location': {'address': '1213 E 233rd St',
#         'crossStreet': 'Baychester Avenue',
#         'lat': 40.89164018732252,
#         'lng': -73.84089838786122,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89164018732252,
#           'lng': -73.84089838786122}],
#         'distance': 630,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1213 E 233rd St (Baychester Avenue)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4edbac4e775bcc53fc0ed5f8-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8b057ff964a520c38e32e3',
#        'name': 'Rite Aid',
#        'location': {'address': '4389 White Plains Rd',
#         'crossStreet': 'Nereid Ave',
#         'lat': 40.89851188277123,
#         'lng': -73.8553595778686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89851188277123,
#           'lng': -73.8553595778686}],
#         'distance': 806,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4389 White Plains Rd (Nereid Ave)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8b057ff964a520c38e32e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '580806c1d67ca3df6196a793',
#        'name': 'Phillip Carpentry',
#        'location': {'address': '4027 Murdock Ave.',
#         'lat': 40.8915296,
#         'lng': -73.8405777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8915296,
#           'lng': -73.8405777}],
#         'distance': 659,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4027 Murdock Ave.',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'shortName': 'Construction',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '351133016'}},
#       'referralId': 'e-0-580806c1d67ca3df6196a793-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '515a1329e4b0e5686040c8bd',
#        'name': 'Deals',
#        'location': {'address': '4225 White Plains Rd',
#         'lat': 40.894326599946716,
#         'lng': -73.8570135303672,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.894326599946716,
#           'lng': -73.8570135303672}],
#         'distance': 826,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['4225 White Plains Rd',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-515a1329e4b0e5686040c8bd-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50bec2b2e4b0a04b0e6dc92f',
#        'name': 'Bee Line 42 MTA NYCT BX39 MTABus BXM11 (White Plains Road/238th St)',
#        'location': {'lat': 40.89821356300333,
#         'lng': -73.85453259642759,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89821356300333,
#           'lng': -73.85453259642759}],
#         'distance': 730,
#         'postalCode': '10470',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Bronx, NY 10470', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50bec2b2e4b0a04b0e6dc92f-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50521e22e4b02dee62cac7fc',
#        'name': 'Mets Nail',
#        'location': {'lat': 40.89756415867958,
#         'lng': -73.85528491997724,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89756415867958,
#           'lng': -73.85528491997724}],
#         'distance': 751,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Bronx, NY 10466', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50521e22e4b02dee62cac7fc-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d82dc4f8de9721e671f1151',
#        'name': 'Wreckhouse',
#        'location': {'address': '741',
#         'crossStreet': 'neried',
#         'lat': 40.89850956763341,
#         'lng': -73.8553560595481,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89850956763341,
#           'lng': -73.8553560595481}],
#         'distance': 806,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['741 (neried)',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d82dc4f8de9721e671f1151-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56749a79498eafd410b90b66',
#        'name': 'D & A Deli',
#        'location': {'address': '1225 E 233rd St',
#         'lat': 40.88871,
#         'lng': -73.841641,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.88871,
#           'lng': -73.841641}],
#         'distance': 815,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['1225 E 233rd St',
#          'Bronx, NY 10466',
#          'United States']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56749a79498eafd410b90b66-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '511b2022e4b08d6c8cf67ff2',
#        'name': 'Inn At the Border',
#        'location': {'address': '146 West Sanford Boulevard',
#         'crossStreet': 'S Eleventh Ave',
#         'lat': 40.898247785493794,
#         'lng': -73.83864124385997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.898247785493794,
#           'lng': -73.83864124385997}],
#         'distance': 821,
#         'postalCode': '10550',
#         'cc': 'US',
#         'neighborhood': 'South Side',
#         'city': 'Mount Vernon',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['146 West Sanford Boulevard (S Eleventh Ave)',
#          'Mount Vernon, NY 10550',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11a941735',
#          'name': 'Other Nightlife',
#          'pluralName': 'Other Nightlife',
#          'shortName': 'Nightlife',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-511b2022e4b08d6c8cf67ff2-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6d02abe13db60c6b81d7b1',
#        'name': 'Beeline 42 bus - 233 st.',
#        'location': {'address': '233 St',
#         'crossStreet': 'White Plains Rd',
#         'lat': 40.89351888191641,
#         'lng': -73.8572552091591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89351888191641,
#           'lng': -73.8572552091591}],
#         'distance': 856,
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['233 St (White Plains Rd)',
#          'Bronx, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c6d02abe13db60c6b81d7b1-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7eea7d7beb96a21ad64490',
#        'name': 'MTA MaBSTOA Bus Bx31 / Bx39 / BxM11 at 233st Street / White Plains Road',
#        'location': {'address': 'White Plains Road',
#         'crossStreet': '233rd Street',
#         'lat': 40.89341846680429,
#         'lng': -73.85735034942627,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.89341846680429,
#           'lng': -73.85735034942627}],
#         'distance': 866,
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['White Plains Road (233rd Street)',
#          'Bronx, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7eea7d7beb96a21ad64490-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bb6aa8765cdf8002ce7689b',
#        'name': 'Fever Tropical Cuisine',
#        'location': {'lat': 40.892555,
#         'lng': -73.857666,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.892555,
#           'lng': -73.857666}],
#         'distance': 912,
#         'postalCode': '10466',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['New York, NY 10466', 'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a00',
#          'name': 'Comfort Food Restaurant',
#          'pluralName': 'Comfort Food Restaurants',
#          'shortName': 'Comfort Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1034013',
#         'url': 'https://www.seamless.com/menu/fever-tropical-cuisine-4164a-white-plains-rd-bronx/1034013?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1034013',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bb6aa8765cdf8002ce7689b-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e17072118388d0d26849fcc',
#        'name': 'Seton Falls Park',
#        'location': {'crossStreet': 'Baychester Avenue & Crawford Avenue',
#         'lat': 40.8884138255166,
#         'lng': -73.84018621289728,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.8884138255166,
#           'lng': -73.84018621289728}],
#         'distance': 915,
#         'cc': 'US',
#         'city': 'Bronx',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['Baychester Avenue & Crawford Avenue',
#          'Bronx, NY',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e17072118388d0d26849fcc-43'}]}]}}

# %% [markdown]
# All data are represented in JSON objects is in the *items* key format.
#
# Before we proceed, let's borrow the **get_category_type** function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### The next step is to clean the Json data and structure it into a pandas dataframe

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                           name            categories        lat        lng
# 0             Lollipops Gelato          Dessert Shop  40.894123 -73.845892
# 1           Ripe Kitchen & Bar  Caribbean Restaurant  40.898152 -73.838875
# 2              Ali's Roti Shop  Caribbean Restaurant  40.894036 -73.856935
# 3  Jackie's West Indian Bakery  Caribbean Restaurant  40.889283 -73.843310
# 4                     Rite Aid              Pharmacy  40.896649 -73.844846

# %% [markdown]
# ### Explore Neighborhoods in Bronx

# %% [markdown]
# #### Lets Create a function to repeat the same process for all neighborhoods in the Bronx that has middle eastern retrurants.  We use the Category ID 4bf58dd8d48988d115941735 to narrow our seatch to middle eastern resturants only.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    CATID = '4bf58dd8d48988d115941735'
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
         CATID)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now write the code to run the above function on each neighborhood and create a new dataframe called *Bronx_venues*.  (Middle Eastern Resturants only)

# %%
bronx_venues = getNearbyVenues(names=bronx_data['Neighborhood'],
                                   latitudes=bronx_data['Latitude'],
                                   longitudes=bronx_data['Longitude']
                                  )
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Claremont Village
# Concourse Village
# Mount Eden
# Mount Hope
# Bronxdale
# Allerton
# Kingsbridge Heights

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will direct our efforts on detecting areas of bronx  that have limited number of middle eastern resturants.  We will limit our analysis to area ~1km around  the Bronx city center.
#
# In first step we have collected the required **data: location and type (category) of every restaurant within 1km from Bronx center**. We will **identify  restaurants** (according to Foursquare categorization).
#
#
# In second and final step we will focus on most promising areas and within those create **clusters of locations that meet some basic requirements** established in discussion with stakeholders: we will take into consideration locations with **no more than two restaurants in radius of 250 meters**, and we want locations **without Middle Eastern restaurants in radius of 1000 meters**. We will present map of all such locations but also create clusters (using **k-means clustering**) of those locations to identify general zones / neighborhoods / addresses which should be a starting point for final 'street level' exploration and search for optimal venue location by stakeholders.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Next, let's group rows by neighborhood and by taking the count  of the frequency of occurrence of each area.  We can use the grouped data to see where are the middle eastern resturans.  We can use two approches, we can select the areas with high concentrations of middle eastern resturants, this insures that there is a market for this type of food.  The other approch we select areas with no middle eastern resturnant frequency the compition is less but the risk may be high.

# %%
print(bronx_venues.shape)
bronx_venues.head()
bronx_venues.groupby('Neighborhood').count()
# Out:
# (15, 7)
#                      Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Bedford Park                             1                       1      1
# Bronxdale                                3                       3      3
# Concourse                                1                       1      1
# Concourse Village                        1                       1      1
# Hunts Point                              1                       1      1
# Kingsbridge Heights                      1                       1      1
# Morris Heights                           1                       1      1
# Morrisania                               1                       1      1
# Mount Eden                               1                       1      1
# Norwood                                  1                       1      1
# Van Nest                                 3                       3      3
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Bedford Park                      1                1               1
# Bronxdale                         3                3               3
# Concourse                         1                1               1
# Concourse Village                 1                1               1
# Hunts Point                       1                1               1
# Kingsbridge Heights               1                1               1
# Morris Heights                    1                1               1
# Morrisania                        1                1               1
# Mount Eden                        1                1               1
# Norwood                           1                1               1
# Van Nest                          3                3               3

# %%
bronx_onehot["Middle Eastern Restaurant"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-225f7dd60a9b> in <module>
# ----> 1 bronx_onehot["Middle Eastern Restaurant"].count()
#
# NameError: name 'bronx_onehot' is not defined

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Looking at the result above, we notice the maximum number of Middle Eastern restaurants are in two areas with each 3 restaurants.   According to the methodology I choose, these two areas will be my top pics.    Before making the final decision, we will examine the demographics of each area.   The areas with higher population and with high concentrations of Middle Eastern population will be my choice.
#
# **Bronxdale**
# Bronxdale population is 79, 188.   The demographics of Bronxdale is made of the following
#
# <li> Citizen US Born	44,972
# <li> Citizen Not US Born 	21,611
# <li> Not Citizens 	12,605
#
#
# <br>
#
# **Van Nest**
# Van Nest population is 20,069.   The demographics of Bronxdale is made of the following
#
#
# <li> Citizen US Born	    11,370
# <li> Citizen Not US Born 	5,378
# <li> Not Citizens 	        3,321
#
#
# <br>
#
# From the above data, I would choose Bronx dale since it has higher population and large number of immigrants.  This will increase the success of the restaurant

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify a location in the Bronx where I can open a Middle Eastern restaurant.  Since I don’t have lots of funds, I wanted to minimize the risk of failure and increase the chances of success.   Bronxdale, has high number of Middle Eastern restaurants.  This means that Middle Eastern restaurants are popular.  The other factor demographics.  It looks like Bronxdale has much higher population then Van Nest, this can be translated into higher revenue if we brand ourselves on pricing and quality food.  My plan, is to makes all meals affordable that way we can transform existing competition into business opportunities.
